# %%
from pylab import *
import pandas as pd
root_log = "../test/lightning_logs/version_139/"
res =  pd.read_csv(root_log+"/K562_2000_merged_histones_init_prediction.csv")
#data = pd.read_csv("../data/K562_2000_merged_histones_init.csv.gz")

# %% [markdown]
# # Compare the signals

# %%
plot(data[sub]["initiation"]/max(data[sub]["initiation"]))
plot(res["res"])

sub = data.chrom=="chr1"
xlim(5000,10000)
# Out:
# (5000.0, 10000.0)

# %% [markdown]
# # Check the loss

# %%
loss = pd.read_csv(root_log+"metrics.csv")
#loss

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
xlim(10000,30000)
ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["val_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["val_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
f = figure(figsize=(10,10))
f.add_subplot(211)
plot(loss["val_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
f.add_subplot(212)
lr = loss["lr-Adadelta"]
lr[~np.isnan(lr)]
plot(lr,"o")

# %%
f = figure(figsize=(10,10))
f.add_subplot(211)
plot(loss["val_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
f.add_subplot(212)
lr = loss["lr-Adadelta"]
lr[~np.isnan(lr)]
plot(lr,"o")

# %%
# Out:
# 0        1.000
# 1139     1.000
# 2279     1.000
# 3419     1.000
# 4558     1.000
# 5698     1.000
# 6838     1.000
# 7977     1.000
# 9117     0.500
# 10257    0.500
# 11397    0.500
# 12536    0.500
# 13676    0.500
# 14816    0.250
# 15955    0.250
# 17095    0.250
# 18235    0.250
# 19374    0.250
# 20514    0.250
# 21654    0.250
# 22794    0.250
# 23933    0.250
# 25073    0.125
# Name: lr-Adadelta, dtype: float64
