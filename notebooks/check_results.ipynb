# %%
from pylab import *
import pandas as pd
root_log = "../test/lightning_logs/version_111/"
res =  pd.read_csv(root_log+"/K562_2000_merged_histones_init_prediction.csv")
#data = pd.read_csv("../data/K562_2000_merged_histones_init.csv.gz")

# %% [markdown]
# # Compare the signals

# %%
plot(data[sub]["initiation"]/max(data[sub]["initiation"]))
plot(res["res"])

sub = data.chrom=="chr1"
xlim(3000,4000)
# Out:
# (3000.0, 4000.0)

# %% [markdown]
# # Check the loss

# %%
loss = pd.read_csv(root_log+"metrics.csv")
#loss

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
xlim(10000,30000)
ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()

# %%
plot(loss["validation_loss_epoch"],"o",label="validation")
plot(loss["training_loss_epoch"],"o",label="train")
#xlim(10000,30000)
#ylim(0.0005,0.002)
legend()
